# %% [markdown]
# ## Fit and analyze decoder models
# The next step of the BehaveNet pipeline is using simultaneously recorded neural activity to predict behavior. Specifically, we can predict either of our compressed descriptions of behavior: the convolutional autoencoder latents or the ARHMM states.
#
# We use linear models or feedforward deep networks to predict the state or latents for a given frame given a window of neural activity. We then compare our predictions to baseline (aka chance) performance. We can also use the convolutional autoencoder to convert the predicted latents into a full predicted behavioral video and compare to the original behavior.
#
#
# <br>
#
# ### Contents
# * [Decoding discrete states](#Decoding-discrete-states)
# * [Decoding continuous latents](#Decoding-continuous-latents)
# * [Assess decoding performance](#Assess-decoding-performance)
# * [Plot true vs predicted latents](#Plot-true-vs-predicted-latents)
# * [Make real vs predicted movies](#Make-real-vs-predicted-movies)

# %%
import time
import pickle
import scipy
import scipy.io as sio
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from tqdm import tqdm

matplotlib.rcParams.update({'font.size': 18, 'figure.figsize': (16, 8)})
from behavenet import get_user_dir, make_dir_if_not_exists
from behavenet.data.utils import get_transforms_paths
from behavenet.data.utils import load_labels_like_latents
from behavenet.fitting.utils import get_expt_dir
from behavenet.fitting.utils import get_session_dir
from behavenet.fitting.utils import get_best_model_version
from behavenet.fitting.utils import get_lab_example
from behavenet.plotting.arhmm_utils import *

from behavenet.fitting.utils import get_best_model_and_data
from behavenet.fitting.eval import export_predictions
from behavenet.models import Decoder

save_outputs = True  # true to save figures/movies to user's figure directory
format = 'png'  # figure format ('png' | 'jpeg' | 'pdf'); movies saved as mp4

from sklearn.metrics import r2_score

# %%
SESS_ID = 'session_2'
SESS_NUM = 2

# %%
from behavenet.fitting.utils import get_subdirs
import os
          
def latent_results(expt_name=None, sess_id=SESS_ID, version='best'):
    # set model info
    sess_idx = 0
    hparams = {
        'data_dir': get_user_dir('data'),
        'save_dir': get_user_dir('save'),
        'model_class': 'neural-ae',
        'ae_model_type': 'conv',
        'ae_experiment_name': 'latent_search',
        'n_ae_latents': 9,
        'experiment_name':'grid_search',
        'model_type':'ff',
        'n_max_lags': 8,
        'rng_seed_data': 0,
        'trial_splits': '8;1;1;0'
    }

    hparams['neural_ae_experiment_name'] = hparams['experiment_name']
    hparams['neural_ae_model_type'] = hparams['model_type']
    hparams['neural_ae_version'] = version
    
    get_lab_example(hparams, 'dipoppa', sess_id)
    
    hparams['session_dir'], sess_ids = get_session_dir(hparams)
    expt_dir = get_expt_dir(hparams)

    ## Get discrete chance performance (accuracy of always predicting the most common training state)
    _, latents_file = get_transforms_paths('ae_latents', hparams, sess_ids[sess_idx])
    with open(latents_file, 'rb') as f:
        all_latents = pickle.load(f)
    mean_ae_latents = np.mean(np.concatenate([all_latents['latents'][i] for i in all_latents['trials']['train']]),axis=0)

    all_test_latents = np.concatenate([all_latents['latents'][i][hparams['n_max_lags']:-hparams['n_max_lags']] for i in all_latents['trials']['test']])
    chance_ae_performance = np.mean((all_test_latents-mean_ae_latents)**2)
    
    ## Get discrete prediction performance
    # If sub-sampling - make sure to get results labelled by sample method and index name 
    if expt_name is not None:
        hparams['subsample_method'] = 'single'
        hparams['subsample_idxs_name'] = expt_name
        
    
    _, latent_predictions_file = get_transforms_paths('neural_ae_predictions', hparams, sess_ids[sess_idx])

    
    if not os.path.exists(latent_predictions_file):
        model, data_generator = get_best_model_and_data(hparams, Decoder, load_data=True, version=version)
        predictions = export_predictions(data_generator, model)
        
    with open(latent_predictions_file, 'rb') as f:
        all_latent_predictions = pickle.load(f)
    all_test_latent_predictions = np.concatenate([all_latent_predictions['predictions'][i][hparams['n_max_lags']:-hparams['n_max_lags']] for i in all_latents['trials']['test']])
    decoding_ae_performance = np.mean((all_test_latents-all_test_latent_predictions)**2)
    r2 = r2_score(all_test_latents, all_test_latent_predictions)
    
    return chance_ae_performance, decoding_ae_performance, r2

# %%
plt.style.use('fivethirtyeight')

# %%
df = get_tags('exc85_sample_0', version=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-af3fb2407ee9> in <module>
# ----> 1 df = get_tags('exc85_sample_0', version=0)
#
# NameError: name 'get_tags' is not defined

# %%
df

# %%
#chance, inh_all = latent_results('inh_all')
_, sst_reg = latent_results('sst85_sample_0', version=0)


_, exc_reg = latent_results('exc85_sample_0', version=0)


chance, all_ = latent_results()

#plt.axvline(inh_all, color='b', linewidth=2, label='inh all')
plt.axvline(sst_reg, color='#FAA31B', linewidth=5, label='SST Linear Regression')

plt.axvline(exc_reg, color='#88C6ED', linewidth=5, label='Exc Linear Regression')


plt.axvline(all_, color='#82C341', linewidth=5, label='All Neurons (1-Layer NN)')
plt.axvline(chance, color='black', linewidth=5, label='Chance Level Prediction')

plt.xlabel('Mean Squared Error')

plt.title('Latent Decoding Models vs. Cell Type', pad=10)
plt.legend()

# %% [markdown]
# # Decoding across cell types

# %%
# Inhibitory Decoding Performance (SST Neurons):
sst_mse = 0
for i in range(10):
    expt_name = 'sst85_sample_' + str(i)
    chance_performance, inh_decoding_performance = latent_results(expt_name=expt_name)
    sst_mse += inh_decoding_performance
    
# inh_decoding_performance = rsquared(inh_decoding_performance, chance_performance)

#Excitatory Decoding Performance:
sample_sizes = range(10)
exc_decoding_errors = []
for size in sample_sizes:
    chance_performance, decoding_performance = latent_results(expt_name='exc85_sample_{}'.format(size))
    exc_decoding_errors.append(decoding_performance)

# %%
from behavenet.fitting.utils import get_best_model_version

def get_tags(expt, version='best', sess_id='session_1'):
    hparams = {
        'data_dir': get_user_dir('data'),
        'save_dir': get_user_dir('save'),
        'model_class': 'neural-ae',
        'ae_model_type': 'conv',
        'ae_experiment_name': 'latent_search',
        'n_ae_latents': 9,
        'experiment_name':'grid_search',
        'model_type':'ff',
        'n_max_lags': 8,
        'rng_seed_data': 0,
        'trial_splits': '8;1;1;0'
    }
    
    hparams['neural_ae_experiment_name'] = hparams['experiment_name']
    hparams['neural_ae_model_type'] = hparams['model_type']
    if expt != 'all':
        hparams['subsample_method'] = 'single'
        hparams['subsample_idxs_name'] = expt
    
    get_lab_example(hparams, 'dipoppa', sess_id)
    
    hparams['session_dir'], sess_ids = get_session_dir(hparams)
    expt_dir = get_expt_dir(hparams)
    
    if version is 'best':
        version = get_best_model_version(expt_dir)[0]
        
    print(version)
    version_dir = os.path.join(expt_dir, 'version_%i' % version)
    df = pd.read_csv(os.path.join(version_dir, 'meta_tags.csv'))
    return df

# %%
df1 = get_tags('all')
# Out:
# 7

# %%
df2 = get_tags('sst85_sample_0')
# Out:
# 0

# %%
df1 = get_tags('all')
df2 = get_tags('sst85_sample_0')

for key in df1['key']:
    try:
        val1 = df1.loc[df1['key'] == key, 'value'].iloc[0]
        val2 = df2.loc[df2['key'] == key, 'value'].iloc[0]
        if val1 != val2:
            print(key, val1, val2)
    except:
        print('Key does not exist: ', key)
        print('df1 value: ', val1)
# Out:
# 7
# 0
# n_hid_layers 2 0
# sessions_csv nan nan
# subsample_idxs_dataset exc85_sample_0 all
# subsample_method none single
# ae_multisession nan nan
# rng_seed_train nan nan
# device cpu cuda
# hpc_exp_number nan nan
# expt_dir /home/samsung_2tb_ssd/yoni/results/dipoppa/full_trial/MD0ST5/1/neural-ae/09_latents/ff/all/grid_search /home/samsung_2tb_ssd/yoni/results/dipoppa/full_trial/MD0ST5/1/neural-ae/09_latents/ff/sst85_sample_0-single/grid_search
# version 7 0
# input_size 1452 85
# Key does not exist:  model_build_rnd_seed
# df1 value:  tensor([0, 0, 0,  ..., 0, 0, 0], dtype=torch.uint8)
# Key does not exist:  training_rnd_seed
# df1 value:  tensor([0, 0, 0,  ..., 0, 0, 0], dtype=torch.uint8)

# %%
hparams = {
    'data_dir': get_user_dir('data'),
    'save_dir': get_user_dir('save'),
    'model_class': 'neural-ae',
    'ae_model_type': 'conv',
    'ae_experiment_name': 'latent_search',
    'n_ae_latents': 9,
    'experiment_name':'grid_search',
    'model_type':'ff',
    'n_max_lags': 8,
    'rng_seed_data': 0,
    'trial_splits': '8;1;1;0'
}

hparams['neural_ae_experiment_name'] = hparams['experiment_name']
hparams['neural_ae_model_type'] = hparams['model_type']
hparams['subsample_method'] = 'single'
hparams['subsample_idxs_name'] = 'sst85_sample_1'

get_lab_example(hparams, 'dipoppa', 'session_1')

hparams['session_dir'], sess_ids = get_session_dir(hparams)
model, data_generator = get_best_model_and_data(hparams, Decoder, load_data=True, version='best')
predictions = export_predictions(data_generator, model)
# Out:
# Loading model defined in /home/samsung_2tb_ssd/yoni/results/dipoppa/full_trial/MD0ST5/1/neural-ae/09_latents/ff/sst85_sample_1-single/grid_search/version_0/meta_tags.pkl
# saving predictions 1 of 1 to /home/samsung_2tb_ssd/yoni/results/dipoppa/full_trial/MD0ST5/1/neural-ae/09_latents/ff/sst85_sample_1-single/grid_search/version_0/dipoppa_full_trial_MD0ST5_1_predictions.pkl

# %%
plt.style.use('seaborn-bright')

# %%
plt.title('[Session #{}] Mean Squared Error Distribution Over 50 Trials'.format(SESS_NUM))
sns.distplot(exc_decoding_errors, hist=False, kde_kws={'color':'red', 'shade':True}, color='red', rug=True, label='85 Putative Excitatory Neurons')

# percentile = exc_decoding_errors.copy()
# percentile.append(inh_decoding_performance)
# percentile.sort()
# inh_percentile = (percentile.index(inh_decoding_performance) - 1) / len(percentile) * 100

p_val = scipy.stats.ttest_1samp(exc_decoding_errors, chance_performance)
print(p_val[0], p_val[1])

plt.axvline(sst_mse / 10, color='b', label='85 SST Neurons')
plt.axvline(chance_performance, color='y', label='Chance decoding performance')
plt.legend()

# print(np.percentile(percentile, 4.3), inh_decoding_performance)
# print('Percentile SST: %d' % inh_percentile)
# Out:
# -18.586904277973787 1.731041426024752e-08

# %% [markdown]
# # Decoding by number of neurons

# %%
sample_sizes = [1, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1200,1452]
decoding_errors_dict = {}
for i, SESS_ID in enumerate(['session_1', 'session_2', 'session_3', 'full_trial']):
    decoding_errors_dict[i] = {}
    for _, size in enumerate(sample_sizes):
        decoding_errors_dict[i][size] = []
        for t in range(10):
            chance_performance, decoding_performance = latent_results(expt_name='sample_{}_t{}'.format(size, t))
            decoding_errors_dict[i][size].append(decoding_performance)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-fe43b80fa3cf> in <module>
#       6         decoding_errors_dict[i][size] = []
#       7         for t in range(10):
# ----> 8             chance_performance, decoding_performance = latent_results(expt_name='sample_{}_t{}'.format(size, t))
#       9             decoding_errors_dict[i][size].append(decoding_performance)
#
# <ipython-input-3-8302c2d3111f> in latent_results(expt_name, sess_id, version)
#      44
#      45
# ---> 46     _, latent_predictions_file = get_transforms_paths('neural_ae_predictions', hparams, sess_ids[sess_idx])
#      47
#      48
#
# ~/behavenet/behavenet/data/utils.py in get_transforms_paths(data_type, hparams, sess_id, check_splits)
#     416             else:
#     417                 neural_ae_version = 'version_%i' % get_best_model_version(
# --> 418                     neural_ae_dir, 'val_loss')[0]
#     419             neural_ae_predictions = str('%spredictions.pkl' % sess_id_str)
#     420             path = os.path.join(neural_ae_dir, neural_ae_version, neural_ae_predictions)
#
# ~/behavenet/behavenet/fitting/utils.py in get_best_model_version(expt_dir, measure, best_def, n_best)
#     907     import pandas as pd
#     908     # gather all versions
# --> 909     versions = get_subdirs(expt_dir)
#     910     # load csv files with model metrics (saved out from test tube)
#     911     metrics = []
#
# ~/behavenet/behavenet/fitting/utils.py in get_subdirs(path)
#      31     """
#      32     if not os.path.exists(path):
# ---> 33         raise ValueError('%s is not a path' % path)
#      34     try:
#      35         s = next(os.walk(path))[1]
#
# ValueError: /home/samsung_2tb_ssd/yoni/results/dipoppa/full_trial/MD0ST5/2/neural-ae/09_latents/ff/sample_1_t0-single/grid_search is not a path

# %%
from scipy import stats

def random_color():
    rgbl=[255,0,0]
    random.shuffle(rgbl)
    return tuple(rgbl)

def avg_dict(data):
    return np.array([np.mean(data[i]) for i in data])

def plot_log(data, xticks, ax, std_error=None, label='', color=None, log=True, measure='MSE', best_fit='plot'):
    if not color:
        color = random_color()
        
    ax.plot(xticks, data, color, label=label)
    
    # Calculate Line of Best Fit 
    slope, intercept = np.polyfit(xticks, data, 1)
    abline_values = [slope * i + intercept for i in xticks]
    if best_fit == 'plot':
        # label=r'Line of Best Fit, $\alpha=%.3f$'%(slope)
        ax.plot(xticks, abline_values, '--', color=color)
    
    # Fill in standard error
    if not std_error is None:
        plt.fill_between(xticks, data+std_error, data-std_error, color=color, alpha=0.3)
    
    if log:
        ax.set_xscale('symlog')
        ax.set_yscale('symlog')
    
    ax.set_xlabel('Number of Neurons')
    if measure == 'r2':
        measure = r'$R^2$'
    ax.set_ylabel(measure)
    ax.set_title('Behavenet Latent Decoding Error by Number of Neurons')
    
 
    return slope, abline_values

# %%
fig, ax = plt.subplots(figsize=(16,8))

measure = 'mse' # 'mse' for Mean Squared Error or 'r2' for R^2
best_fit = 'average' # 'average' returns line of best fit values for averaging | 'plot' plots individual lines
best_fits = []
slopes = []
start_index = 0 # Index to start plotting from

for i in range(4):
    # Calculate standard errors
    std_error = np.array([stats.sem(decoding_errors_dict[i][k] / chance_performance) 
                          for k in decoding_errors_dict[i]])[start_index:] 
    # Average errors across all tests in a sample size
    avg_errors = avg_dict(decoding_errors_dict[i])[start_index:]
    avg_errors /= chance_performance
    if best_fit == 'average':
        slope, abline_vals = plot_log(avg_errors, 
                                      sample_sizes[start_index:], 
                                      ax, 
                                      std_error=std_error, 
                                      best_fit='average', 
                                      measure=measure, 
                                      session=i+1)
        slopes.append(slope)
        best_fits.append(abline_vals)
    else:
        plot_log(avg_errors, 
                 sample_sizes[start_index:], 
                 ax, std_error=std_error, 
                 measure=measure, 
                 session=i+1)
    
# Average line of best fit
if best_fit == 'average':
    slope = np.mean(slopes)
    abline_values = np.mean(best_fits, axis=0) 
    ax.plot(sample_sizes[start_index:], np.power(np.e, abline_values), '--', color='k', label=r'Average Line of Best Fit, $\alpha=%.3f$'%(slope))

# Remove duplicates from legend
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())
plt.show()
# Out:
# /home/yoni/.conda/envs/behavenet/lib/python3.7/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/yoni/.conda/envs/behavenet/lib/python3.7/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/yoni/.conda/envs/behavenet/lib/python3.7/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/yoni/.conda/envs/behavenet/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/yoni/.conda/envs/behavenet/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-33a045281c68> in <module>
#      21                                       best_fit='average',
#      22                                       measure=measure,
# ---> 23                                       session=i+1)
#      24         slopes.append(slope)
#      25         best_fits.append(abline_vals)
#
# <ipython-input-18-2f786cb798dc> in plot_log(data, xticks, ax, std_error, session, log, measure, best_fit)
#       5
#       6 def plot_log(data, xticks, ax, std_error=None, session=1, log=True, measure='MSE', best_fit='plot'):
# ----> 7     ax.plot(xticks, data)
#       8
#       9     # Calculate Line of Best Fit
#
# ~/.conda/envs/behavenet/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/.conda/envs/behavenet/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# ~/.conda/envs/behavenet/lib/python3.7/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# ~/.conda/envs/behavenet/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# ~/.conda/envs/behavenet/lib/python3.7/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (13,) and (1,)

# %%
latent_results(expt_name='sst85_sample_9')
# Out:
# (12.409013, 11.080230152402368)

# %%
# ################## Set Initial hyperparameters ####################
hparams = {
    'data_dir': get_user_dir('data'),
    'save_dir': get_user_dir('save'),
    'model_class': 'neural-ae',
    'ae_model_type': 'conv',
    'ae_experiment_name': 'latent_search',
    'n_ae_latents': 9,
    'experiment_name':'grid_search',
    'model_type':'ff',
    'n_max_lags': 8
}
hparams['neural_ae_experiment_name'] = hparams['experiment_name']
hparams['neural_ae_model_type'] = hparams['model_type']
######################################################################

session_ids = ['session_1', 'session_2', 'session_3', 'full_trial']
sample_sizes = [1, 2, 4, 6, 8, 10, 20, 30, 40, 50, 60, 70, 80, 85]
cell_types = ['sst', 'exc']
num_trials = 10

data_dict = {}

expt_count = 0
start = time.time()
for i, sess_id in enumerate(session_ids):
    print('Loading data for Session: #%d...'%(i+1))
    
    get_lab_example(hparams, 'dipoppa', sess_id)
    hparams['session_dir'], sess_ids = get_session_dir(hparams)
    hparams['subsample_method'] = 'single'
    
    data_dict[i] = {}
    sess_dict = data_dict[i]
    for ctype in cell_types:
        print('Loading %s data...'%ctype)
        sess_dict[ctype] = {}
        sess_dict[ctype]['mse'] = {}
        sess_dict[ctype]['r2'] = {}
        sess_dict[ctype]['chance'] = {}
        
        for size in tqdm(sample_sizes):
            sess_dict[ctype]['mse'][size] = []
            sess_dict[ctype]['r2'][size] = []
            sess_dict[ctype]['chance'][size] = 0
            for t in range(num_trials):
                expt_name ='{}{}_sample_{}'.format(ctype, size, t)
                hparams['subsample_idxs_name'] = expt_name

                chance_performance, mse, r2 = latent_results(expt_name=expt_name, sess_id=sess_id)
                sess_dict[ctype]['mse'][size].append(mse)
                sess_dict[ctype]['r2'][size].append(r2)
                sess_dict[ctype]['chance'][size] = chance_performance
                
                expt_count += 1
                
end = time.time()               
print('Loaded data from {} experiments in {} seconds'.format(expt_count, end-start))
# Out:
#   0%|          | 0/14 [00:00<?, ?it/s]
# Loading data for Session: #1...
# Loading sst data...
# 100%|██████████| 14/14 [00:06<00:00,  2.24it/s]
#   0%|          | 0/14 [00:00<?, ?it/s]
# Loading exc data...
# 100%|██████████| 14/14 [00:06<00:00,  2.13it/s]
#   0%|          | 0/14 [00:00<?, ?it/s]
# Loading data for Session: #2...
# Loading sst data...
# 100%|██████████| 14/14 [00:06<00:00,  1.96it/s]
#   0%|          | 0/14 [00:00<?, ?it/s]
# Loading exc data...
# 100%|██████████| 14/14 [00:06<00:00,  2.23it/s]
#   0%|          | 0/14 [00:00<?, ?it/s]
# Loading data for Session: #3...
# Loading sst data...
# 100%|██████████| 14/14 [00:06<00:00,  2.41it/s]
#   0%|          | 0/14 [00:00<?, ?it/s]
# Loading exc data...
# 100%|██████████| 14/14 [00:06<00:00,  2.23it/s]
#   0%|          | 0/14 [00:00<?, ?it/s]
# Loading data for Session: #4...
# Loading sst data...
# 100%|██████████| 14/14 [00:06<00:00,  2.13it/s]
#   0%|          | 0/14 [00:00<?, ?it/s]
# Loading exc data...
# 100%|██████████| 14/14 [00:06<00:00,  2.17it/s]
# Loaded data from 1120 experiments in 51.00813579559326 seconds

# %%
fig, ax = plt.subplots(figsize=(16,8))

measure = 'mse' # 'mse' for Mean Squared Error or 'r2' for R^2
best_fit = 'average' # 'average' returns line of best fit values for averaging | 'plot' plots individual lines

chance_norm = True
best_fits = {}
for ctype in cell_types:
    best_fits[ctype] = {}
    
start_index = 0 # Index to start plotting from

for color, ctype in zip(['blue', 'red'], cell_types):
    best_fits[ctype]['line'] = []
    best_fits[ctype]['slope'] = []
    
    for i in range(4):
        data = data_dict[i][ctype][measure]

        std_error = np.array([stats.sem(data[k]) for k in data])[start_index:] 
        avg_errors = avg_dict(data)[start_index:]
        
        if chance_norm:
            chance = avg_dict(data_dict[i][ctype]['chance'])
            avg_errors /= chance
            std_error /= chance
            
            ax.axhline(y=1, xmin=0.045, color='black', linewidth=2, alpha=0.8, label='chance decoding')
            
        slope, abline_vals = plot_log(avg_errors, 
                                      sample_sizes[start_index:], 
                                      ax, 
                                      std_error=std_error, 
                                      best_fit=best_fit, 
                                      measure=measure, 
                                      label='{} Neurons'.format(ctype), color=color)
        
        best_fits[ctype]['line'].append(abline_vals)
        best_fits[ctype]['slope'].append(slope)
        
    
# Average line of best fit
if best_fit == 'average':
    sst_slope = np.mean(best_fits['sst']['slope'])
    abline_values = np.mean(best_fits['sst']['line'], axis=0) 
    #label=r'sst Average Line of Best Fit, $\alpha=%.3f$'%(sst_slope)
    ax.plot(sample_sizes[start_index:], abline_values, '--', color='blue')

    exc_slope = np.mean(best_fits['exc']['slope'])
    abline_values = np.mean(best_fits['exc']['line'], axis=0) 
    # label=r'exc Average Line of Best Fit, $\alpha=%.3f$'%(exc_slope)
    ax.plot(sample_sizes[start_index:], abline_values, '--', color='red')


# Remove duplicates from legend
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())
plt.show()

# %%
from behavenet.fitting.utils import get_best_model_and_data
from behavenet.fitting.eval import export_predictions
from behavenet.models import Decoder

sample_sizes = [1, 2, 4, 6, 8, 10, 20, 30, 40, 50, 60, 70, 80, 85]
sst_decoding_dict = {}
exc_decoding_dict = {}

sst_decoding_dict['mse'] = {}
sst_decoding_dict['r2'] = {}
sst_decoding_dict['chance'] = {}

exc_decoding_dict['mse'] = {}
exc_decoding_dict['r2'] = {}   
exc_decoding_dict['chance'] = {}

for i, SESS_ID in enumerate(['session_1', 'session_2', 'session_3', 'full_trial']):
    # Set hyperparameters
    hparams = {
        'data_dir': get_user_dir('data'),
        'save_dir': get_user_dir('save'),
        'model_class': 'neural-ae',
        'ae_model_type': 'conv',
        'ae_experiment_name': 'latent_search',
        'n_ae_latents': 9,
        'experiment_name':'grid_search',
        'model_type':'ff',
        'n_max_lags': 8
    }
    hparams['neural_ae_experiment_name'] = hparams['experiment_name']
    hparams['neural_ae_model_type'] = hparams['model_type']

    get_lab_example(hparams, 'dipoppa', SESS_ID)

    hparams['session_dir'], sess_ids = get_session_dir(hparams)
    hparams['subsample_method'] = 'single'

    sst_decoding_dict['mse'][i] = {}
    sst_decoding_dict['r2'][i] = {}
    exc_decoding_dict['mse'][i] = {}
    exc_decoding_dict['r2'][i] = {}
    

    print('Session: #%d'%i)
    for k, size in enumerate(sample_sizes):
        sst_decoding_dict['mse'][i][size] = []
        exc_decoding_dict['mse'][i][size] = []
        
        sst_decoding_dict['r2'][i][size] = []
        exc_decoding_dict['r2'][i][size] = []
        print('Loading data for sample size: %d' % size)
        for t in range(10):
            sst_expt ='sst{}_sample_{}'.format(size, t)
            hparams['subsample_idxs_name'] = sst_expt

            chance_performance, sst_decoding, r2 = latent_results(expt_name=sst_expt, sess_id=SESS_ID)
            sst_decoding_dict['mse'][i][size].append(sst_decoding)
            sst_decoding_dict['r2'][i][size].append(r2)

            exc_expt = 'exc{}_sample_{}'.format(size, t)
            hparams['subsample_idxs_name'] = exc_expt

            chance_performance, exc_decoding, r2 = latent_results(expt_name=exc_expt, sess_id=SESS_ID)
            exc_decoding_dict['mse'][i][size].append(exc_decoding)
            exc_decoding_dict['r2'][i][size].append(r2)
# Out:
# Session: #0
# Loading data for sample size: 1
# Loading data for sample size: 2
# Loading data for sample size: 4
# Loading data for sample size: 6
# Loading data for sample size: 8
# Loading data for sample size: 10
# Loading data for sample size: 20
# Loading data for sample size: 30
# Loading data for sample size: 40
# Loading data for sample size: 50
# Loading data for sample size: 60
# Loading data for sample size: 70
# Loading data for sample size: 80
# Loading data for sample size: 85
# Session: #1
# Loading data for sample size: 1
# Loading data for sample size: 2
# Loading data for sample size: 4
# Loading data for sample size: 6
# Loading data for sample size: 8
# Loading data for sample size: 10
# Loading data for sample size: 20
# Loading data for sample size: 30
# Loading data for sample size: 40
# Loading data for sample size: 50
# Loading data for sample size: 60
# Loading data for sample size: 70
# Loading data for sample size: 80
# Loading data for sample size: 85
# Session: #2
# Loading data for sample size: 1
# Loading data for sample size: 2
# Loading data for sample size: 4
# Loading data for sample size: 6
# Loading data for sample size: 8
# Loading data for sample size: 10
# Loading data for sample size: 20
# Loading data for sample size: 30
# Loading data for sample size: 40
# Loading data for sample size: 50
# Loading data for sample size: 60
# Loading data for sample size: 70
# Loading data for sample size: 80
# Loading data for sample size: 85

# %%
sst_decoding_dict.keys(), exc_decoding_dict.keys()
# Out:
# (dict_keys([0, 1, 2, 3]), dict_keys([0, 1, 2, 3]))

# %%
sst_decoding_dict['r2'][0][85]
# Out:
# [0.12785103558560676,
#  0.12797062489991273,
#  0.12795153456744363,
#  0.12801456457488092,
#  0.12799254185999187,
#  0.12784246093761992,
#  0.12806750666353459,
#  0.1280360004940472,
#  0.12814220765076303,
#  0.1280830269282328]

# %%
np.log(-0.00484778290335355)
# Out:
# /home/yoni/.conda/envs/behavenet/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
# nan

# %%
fig, ax = plt.subplots(figsize=(16,8))

measure = 'mse' # 'mse' for Mean Squared Error or 'r2' for R^2
best_fit = 'average' # 'average' returns line of best fit values for averaging | 'plot' plots individual lines
sst_best_fits = []
exc_best_fits = []
sst_slopes = []
exc_slopes = []
start_index = 0 # Index to start plotting from

for i in range(3):
    # Calculate standard errors
    # SST data:
    std_error_sst = np.array([stats.sem(sst_decoding_dict[measure][i][k]) 
                          for k in sst_decoding_dict[measure][i]])[start_index:] 
    std_error_exc = np.array([stats.sem(exc_decoding_dict[measure][i][k]) 
                          for k in exc_decoding_dict[measure][i]])[start_index:]
    
    # Average errors across all tests in a sample size
    sst_avg_errors = avg_dict(sst_decoding_dict[measure][i])[start_index:]
    exc_avg_errors = avg_dict(exc_decoding_dict[measure][i])[start_index:]
    
    print(len(sst_avg_errors), len(exc_avg_errors), len(sample_sizes[start_index:]))
    if best_fit == 'average':
        sst_slope, sst_abline_vals = plot_log(sst_avg_errors, 
                                      sample_sizes[start_index:], 
                                      ax, 
                                      std_error=std_error_sst, 
                                      best_fit='average', 
                                      measure=measure, 
                                      label='SST Neurons'.format(i), color='blue')
        
        sst_slopes.append(sst_slope)
        sst_best_fits.append(sst_abline_vals)
        
        exc_slope, exc_abline_vals = plot_log(exc_avg_errors, 
                                      sample_sizes[start_index:], 
                                      ax, 
                                      std_error=std_error_exc, 
                                      best_fit='average', 
                                      measure=measure, 
                                      label='Pyr Neurons'.format(i), color='red')
        
        exc_slopes.append(exc_slope)
        exc_best_fits.append(exc_abline_vals)
        
    else:
        plot_log(sst_avg_errors, 
                 sample_sizes[start_index:], 
                 ax, std_error=std_error_sst, 
                         measure='r2', 
                         color='blue',
                            log=True)
        plot_log(exc_avg_errors, 
                 sample_sizes[start_index:], 
                 ax, std_error=std_error_exc, 
                         measure='r2', 
                         color='red', log=True)

    
# Average line of best fit
if best_fit == 'average':
    sst_slope = np.mean(sst_slopes)
    abline_values = np.mean(sst_best_fits, axis=0) 
    ax.plot(sample_sizes[start_index:], abline_values, '--', color='blue', label=r'SST Average Line of Best Fit, $\alpha=%.3f$'%(sst_slope))

    exc_slope = np.mean(exc_slopes)
    abline_values = np.mean(exc_best_fits, axis=0) 
    ax.plot(sample_sizes[start_index:], abline_values, '--', color='red', label=r'PYR Average Line of Best Fit, $\alpha=%.3f$'%(exc_slope))


# Remove duplicates from legend
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())
plt.show()
# Out:
# 14 14 14
# 14 14 14
# 14 14 14

# %%
fig, ax = plt.subplots(figsize=(16,12))

sst_data = avg_dict(sst_decoding_dict)
sst_std_error = [stats.sem(sst_decoding_dict[i]) for i in sst_decoding_dict]
exc_data = avg_dict(exc_decoding_dict)
exc_std_error = [stats.sem(exc_decoding_dict[i]) for i in exc_decoding_dict]


plot_log(sst_data, 
         sample_sizes, 
         ax, std_error=sst_std_error, 
                 measure='mse', 
                 session='SST')
plot_log(exc_data[6:], 
         sample_sizes, 
         ax, std_error=exc_std_error, 
                 measure='mse', 
                 session='Pyr')

plt.legend()
plt.show()

# %%
SESS_ID='session_1'
SESS_NUM='1'

# %% [markdown]
# # Standard Decoding Plot (ARHMM, AE)

# %% [markdown]
# # Single Neuron Decoding

# %%
fig, ax = plt.subplots(figsize=(16,10))
sample_sizes = list(range(20))
decoding_errors = []
for size in sample_sizes:
    chance_performance, decoding_performance = latent_results(sample_size=size, expt_name='exc85_sample')
    decoding_errors.append(decoding_performance)

avg_error = sum(decoding_errors) / 20

plt.hlines(chance_performance, 0, 20, color='blue', label='Chance (Mean) Behavioral State Prediction')   
plt.title('AE Latent Decoding for Single Neurons', fontsize=22)
plt.plot(sample_sizes, decoding_errors, '-o', label='Latent Behavioral State Prediction')
plt.xlabel('Trial', fontsize=18)
plt.ylabel('Mean Squared Error', fontsize=18)
plt.legend()
plt.show()

# %% [markdown]
# ## Plot true vs predicted latents
#
# [Back to contents](#Contents)

# %%
def plot_real_vs_predicted(
        latents, latents_predicted, save_file=None, xtick_locs=None,  frame_rate=None, format='png'):
    """Plot real and sampled latents overlaying real and (potentially sampled) states.
    Parameters
    ----------
    latents : :obj:`np.ndarray`
        shape (n_frames, n_latents)
    latents_samp : :obj:`np.ndarray`
        shape (n_frames, n_latents)
    states : :obj:`np.ndarray`
        shape (n_frames,)
    states_samp : :obj:`np.ndarray`
        shape (n_frames,) if :obj:`latents_samp` are not conditioned on :obj:`states`, otherwise
        shape (0,)
    save_file : :obj:`str`
        full save file (path and filename)
    xtick_locs : :obj:`array-like`, optional
        tick locations in bin values for plot
    frame_rate : :obj:`float`, optional
        behavioral video framerate; to properly relabel xticks
    format : :obj:`str`, optional
        any accepted matplotlib save format, e.g. 'png' | 'pdf' | 'jpeg'
    Returns
    -------
    :obj:`matplotlib.figure.Figure`
        matplotlib figure handle
    """

    fig, ax = plt.subplots(1, 1, figsize=(16, 8))

        
    spc = 1.1 * abs(latents.max())
    n_latents = latents.shape[1]
    plotting_latents = latents + spc * np.arange(n_latents)
    plotting_predicted_latents = latents_predicted + spc * np.arange(n_latents)
    ymin = min(-spc - 1, np.min(plotting_latents))
    ymax = max(spc * n_latents, np.max(plotting_latents))
    ax.plot(plotting_latents, '-k', lw=3, label='AE Latents')
    ax.plot(plotting_predicted_latents, '-g', lw=3, label='Predicted AE latents')
    ax.set_ylim([ymin, ymax])

    ax.set_yticks([])

    ax.set_xlabel('Time (bins)')

    if xtick_locs is not None:
        ax.set_xticks(xtick_locs)
        if frame_rate is not None:
            ax.set_xticklabels((np.asarray(xtick_locs) / frame_rate).astype('int'))
            ax.set_xlabel('Time (sec)')
    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    plt.legend(by_label.values(), by_label.keys(),loc='center left', bbox_to_anchor=(1, 0.5))

    if save_file is not None:
        make_dir_if_not_exists(save_file)
        plt.savefig(save_file, dpi=300, format=format)

# %%
import os

# user params
get_best_version = True  # False when looking at multiple models w/in a tt expt
dtype = 'val'  # data type to draw trials from: 'train' | 'val' | 'test'
sess_idx = 0  # when using a multisession, this determines which session is used
max_frames = 200

# define which arhmm states to plot (must already be fit)
n_arhmm_states = [4, 8]

# set model info
hparams = {
    'data_dir': get_user_dir('data'),
    'save_dir': get_user_dir('save'),
    'experiment_name': 'grid_search',
    'model_class': 'neural-ae',
    'model_type': 'ff',
    'ae_experiment_name': 'latent_search',
    'n_ae_latents': 9,
    'ae_model_type': 'conv',
}

hparams['neural_ae_experiment_name'] = hparams['experiment_name']
hparams['neural_ae_model_type'] = hparams['model_type']

get_lab_example(hparams, 'dipoppa', SESS_ID)

xtick_locs = [0, 30, 60, 90, 120, 150, 180]
frame_rate = 30
n_trials = 10
           
for n_states in n_arhmm_states:
        
    hparams['n_arhmm_states'] = n_states
    hparams['session_dir'], sess_ids = get_session_dir(hparams)
    hparams['expt_dir'] = get_expt_dir(hparams)
    
    # get version/model
    if get_best_version:
        version = get_best_model_version(
            hparams['expt_dir'], measure='val_loss', best_def='max')[0]
    else:
        _, version = experiment_exists(hparams, which_version=True)

    # load model
    model_file = os.path.join(
        hparams['expt_dir'], 'version_%i' % version, 'best_val_model.pt')
    with open(model_file, 'rb') as f:
        hmm = pickle.load(f)
        
            
    # load latents
    _, latents_file = get_transforms_paths('ae_latents', hparams, sess_ids[sess_idx])
    with open(latents_file, 'rb') as f:
        all_latents = pickle.load(f)
    
    _, latents_file = get_transforms_paths('neural_ae_predictions', hparams, sess_ids[sess_idx])

    # choose which trials to plot
    np.random.seed(0)
    trial_vec = np.random.choice(
        np.arange(0, len(all_latents['trials'][dtype])), size=(n_trials,), 
        replace=False)

    with open(latents_file, 'rb') as f:
        predicted_latents = pickle.load(f)

    model_name = str(
        'latent_prediction_D=%02i' % (
        hparams['n_ae_latents']))

    if save_outputs:
        save_file = os.path.join(
            get_user_dir('fig'), hparams['model_class'], model_name + '.' + format)
    else:
        save_file = None
    
    plot_real_vs_predicted(all_latents['latents'][trial_vec[0]], predicted_latents['predictions'][trial_vec[0]], save_file=save_file, xtick_locs=None,  frame_rate=30, format='png')
    plt.title('Latent Reconstruction (85 Random Excitatory Neurons)')

# %% [markdown]
# # Let's create a helpful method to visualize how we've decoded across multiple regions

# %%
def plot_real_vs_predicted_subsampling(
        latents, latents_predicted, save_file=None, xtick_locs=None,  frame_rate=None, format='png'):
    """Plot real and sampled latents overlaying real and (potentially sampled) states.
    Parameters
    ----------
    latents : :obj:`np.ndarray`
        shape (n_frames, n_latents)
    latents_samp : :obj:`np.ndarray`
        shape (n_frames, n_latents)
    states : :obj:`np.ndarray`
        shape (n_frames,)
    states_samp : :obj:`np.ndarray`
        shape (n_frames,) if :obj:`latents_samp` are not conditioned on :obj:`states`, otherwise
        shape (0,)
    save_file : :obj:`str`
        full save file (path and filename)
    xtick_locs : :obj:`array-like`, optional
        tick locations in bin values for plot
    frame_rate : :obj:`float`, optional
        behavioral video framerate; to properly relabel xticks
    format : :obj:`str`, optional
        any accepted matplotlib save format, e.g. 'png' | 'pdf' | 'jpeg'
    Returns
    -------
    :obj:`matplotlib.figure.Figure`
        matplotlib figure handle
    """

    fig, ax = plt.subplots(1, 1, figsize=(10, 8))

        
    spc = 1.1 * abs(latents.max())
    n_latents = latents.shape[1]
    for latent, latent_predicted in zip(latents, latent_predicted):
        plotting_latents = latent + spc * np.arange(n_latents)
        plotting_predicted_latents = latent_predicted + spc * np.arange(n_latents)
        ymin = min(-spc - 1, np.min(plotting_latents))
        ymax = max(spc * n_latents, np.max(plotting_latents))
        ax.plot(plotting_latents, '-k', lw=3, label='AE Latents')
        ax.plot(plotting_predicted_latents, lw=3, label='Predicted AE latents')
        ax.set_ylim([ymin, ymax])

    ax.set_yticks([])

    ax.set_xlabel('Time (bins)')

    if xtick_locs is not None:
        ax.set_xticks(xtick_locs)
        if frame_rate is not None:
            ax.set_xticklabels((np.asarray(xtick_locs) / frame_rate).astype('int'))
            ax.set_xlabel('Time (sec)')
    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    plt.legend(by_label.values(), by_label.keys(),loc='center left', bbox_to_anchor=(1, 0.5))

    if save_file is not None:
        make_dir_if_not_exists(save_file)
        plt.savefig(save_file, dpi=300, format=format)

# %%
# user params
get_best_version = True  # False when looking at multiple models w/in a tt expt
dtype = 'test'  # data type to draw trials from: 'train' | 'val' | 'test'
sess_idx = 0  # when using a multisession, this determines which session is used
max_frames = 200

# define which arhmm states to plot (must already be fit)
n_arhmm_states = [2, 4]

# set model info
hparams = {
    'data_dir': get_user_dir('data'),
    'save_dir': get_user_dir('save'),
    'experiment_name': 'grid_search',
    'model_class': 'neural-ae',
    'model_type': 'ff',
    'ae_experiment_name': 'latent_search',
    'n_ae_latents': 9,
    'ae_model_type': 'conv',
}

hparams['neural_ae_experiment_name'] = hparams['experiment_name']
hparams['neural_ae_model_type'] = hparams['model_type']

get_lab_example(hparams, 'dipoppa', SESS_ID)

xtick_locs = [0, 30, 60, 90, 120, 150, 180]
frame_rate = 30
n_trials = 10
           
for n_states in n_arhmm_states:
        
    hparams['n_arhmm_states'] = n_states
    hparams['session_dir'], sess_ids = get_session_dir(hparams)
    hparams['expt_dir'] = get_expt_dir(hparams)
    print(hparams['expt_dir'])
    # get version/model
    if get_best_version:
        version = get_best_model_version(
            hparams['expt_dir'], measure='val_loss', best_def='max')[0]
    else:
        _, version = experiment_exists(hparams, which_version=True)

    # load model
    model_file = os.path.join(
        hparams['expt_dir'], 'version_%i' % version, 'best_val_model.pt')
    with open(model_file, 'rb') as f:
        hmm = pickle.load(f)
        
            
    # load latents
    _, latents_file = get_transforms_paths('ae_latents', hparams, sess_ids[sess_idx])
    with open(latents_file, 'rb') as f:
        all_latents = pickle.load(f)
    
    _, latents_file = get_transforms_paths('neural_ae_predictions', hparams, sess_ids[sess_idx])

    # choose which trials to plot
    np.random.seed(0)
    trial_vec = np.random.choice(
        np.arange(0, len(all_latents['trials'][dtype])), size=(n_trials,), 
        replace=False)

    with open(latents_file, 'rb') as f:
        predicted_latents = pickle.load(f)

    model_name = str(
        'latent_prediction_D=%02i' % (
        hparams['n_ae_latents']))

    if save_outputs:
        save_file = os.path.join(
            get_user_dir('fig'), hparams['model_class'], model_name + '.' + format)
    else:
        save_file = None

    plot_real_vs_predicted(all_latents['latents'][trial_vec[0]], predicted_latents['predictions'][trial_vec[0]], save_file=save_file, xtick_locs=None,  frame_rate=30, format='png')

# %%
SESS_ID = 'session_3'
SESS_NUM = '3'

# %%
from behavenet.plotting.ae_utils import make_neural_reconstruction_movie_wrapper
from behavenet.data.utils import get_data_generator_inputs
from behavenet.data.data_generator import ConcatSessionsGenerator

# movie info
save_outputs = True
include_linear = False  # True to include reconstructions from linear models; need training

# set model info
version = 'best'  # test-tube version; 'best' finds the version with the lowest mse
sess_idx = 0  # when using a multisession, this determines which session is used
MASTER_HPARAMS = {
    'data_dir': get_user_dir('data'),
    'save_dir': get_user_dir('save'),
    'model_class': 'ae',
    'experiment_name': 'grid_search',
    'model_type': 'ff',
    'ae_model_class': 'ae',
    'ae_model_type': 'conv',
    'ae_version': version,
    'noise_type': 'gaussian',
    'n_arhmm_lags': 1,
    'kappa': 0,
    'ae_experiment_name': 'latent_search',
    'n_ae_latents': 9,
    'neural_arhmm_experiment_name':'grid_search',
    'n_arhmm_states': 4,
    'n_max_lags': 9,
    'decoder_experiment_name': 'grid_search',
    'decoder_model_class': 'neural-ae',
    'decoder_model_type': 'ff',
    'decoder_version': version
}

sess_ids = ['session_1', 'session_2', 'session_3', 'full_trial']
sess_nums = ['1', '2', '3', '4']
expts = ['all', 'inh_all', 'exc85_sample_0', 'sample_100_t0', 'sample_500_t0', 'sample_1000_t0']
for SESS_ID, SESS_NUM in zip(sess_ids, sess_nums):
    for expt_name in expts:
        hparams = MASTER_HPARAMS
        # programmatically fill out other hparams options
        get_lab_example(hparams, 'dipoppa', SESS_ID)   
        hparams['session_dir'], sess_ids = get_session_dir(hparams)
        hparams['expt_dir'] = get_expt_dir(hparams)
        
        if expt_name != 'all':
            hparams['subsample_method'] = 'single'
            hparams['subsample_idxs_name'] = expt_name

        # load data generator to find a test trial
        hparams, signals, transforms, paths = get_data_generator_inputs(hparams, sess_ids)
        data_generator = ConcatSessionsGenerator(
            hparams['data_dir'], sess_ids, 
            signals_list=signals, transforms_list=transforms, paths_list=paths,
            device='cpu', as_numpy=False, batch_load=True, rng_seed=0)
        print(data_generator)
        trial = data_generator.datasets[sess_idx].batch_idxs['test'][2]  # trial to use in movie

        filename = str('%s_D=%02i_reconstruction' % (expt_name, hparams['n_ae_latents']))

        make_neural_reconstruction_movie_wrapper(
            hparams, 
            save_file=os.path.join(get_user_dir('fig'), 'neural-ae', 'full_trial', 'MD0ST5', SESS_NUM, filename), 
            frame_rate=30, max_latents=9, trial=trial)
